# %% [markdown]
# ### After The completion of the data cleaning , i am now working with respect to exploratory data analysis where i would be using the cleaned data to find out new features about the exisisting data

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train_dataset=pd.read_csv("train_dataset.csv")

train_dataset
# Out:
#             id      Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0            0   Mystery Matters    Episode 98                   63.84
# 1            1     Joke Junction    Episode 26                  119.80
# 2            2    Study Sessions    Episode 16                   73.90
# 3            3    Digital Digest    Episode 45                   67.17
# 4            4       Mind & Body    Episode 86                  110.51
# ...        ...               ...           ...                     ...
# 749995  749995      Learning Lab    Episode 25                   75.66
# 749996  749996   Business Briefs    Episode 21                   75.75
# 749997  749997  Lifestyle Lounge    Episode 51                   30.98
# 749998  749998       Style Guide    Episode 47                  108.98
# 749999  749999    Sports Central    Episode 99                   24.10
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
test_dataset = pd.read_csv("test_dataset.csv")

test_dataset
# Out:
#             id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0       750000  Educational Nuggets    Episode 73                   78.96
# 1       750001          Sound Waves    Episode 23                   27.87
# 2       750002        Joke Junction    Episode 11                   69.10
# 3       750003        Comedy Corner    Episode 73                  115.39
# 4       750004         Life Lessons    Episode 50                   72.32
# ...        ...                  ...           ...                     ...
# 249995  999995          Mind & Body   Episode 100                   21.05
# 249996  999996        Joke Junction    Episode 85                   85.50
# 249997  999997        Joke Junction    Episode 63                   12.11
# 249998  999998       Market Masters    Episode 46                  113.46
# 249999  999999          Brain Boost    Episode 46                   78.05
#
#             Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %% [markdown]
# ### Outlier Detection

# %%
def detect_outliers(train_dataset,column):
    q1=train_dataset[column].quantile(0.25)
    q3=train_dataset[column].quantile(0.75)
    IQR = q3-q1
    lower_bound = q1-1.5*IQR
    upper_bound = q3+1.5*IQR
    outliers = train_dataset[(train_dataset[column] < lower_bound)| (train_dataset[column] >upper_bound)][column]
    return len(outliers),lower_bound,upper_bound

outlier_sum={}
for col in train_dataset:
    count,lower,upper = detect_outliers(train_dataset,col)
    outlier_sum[col] = {'outlier_count' :count , 'Lower_Bound' : lower, "Upper_Bound" : upper}
    
outlier_df = pd.DataFrame(outlier_sum).T
outlier_df = outlier_df.sort_vakyes("outlier_count",ascending = False)
print(outlier_df.head(10))
print("Columns with outliers : ",len(outlier_df[outlier_df['outlier_count']>0]))
print("maximum outliers in a column : ",outkuer_df['outlier_count'].max())
print(" Percentage of outliers in top column :",(outlier_df['outlier_count'].max()/ train_dataset.shape[0])*100, '%')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 12
#      10 outlier_sum={}
#      11 for col in train_dataset:
# ---> 12     count,lower,upper = detect_outliers(train_dataset,col)
#      13     outlier_sum[col] = {'outlier_count' :count , 'Lower_Bound' : lower, "Upper_Bound" : upper}
#      15 outlier_df = pd.DataFrame(outlier_sum).T
#
# Cell In[5], line 2, in detect_outliers(train_dataset, column)
#       1 def detect_outliers(train_dataset,column):
# ----> 2     q1=train_dataset[column].quantile(0.25)
#       3     q3=train_dataset[column].quantile(0.75)
#       4     IQR = q3-q1
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:2650, in Series.quantile(self, q, interpolation)
#    2646 # We dispatch to DataFrame so that core.internals only has to worry
#    2647 #  about 2D cases.
#    2648 df = self.to_frame()
# ...
